# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import networkx as nx
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
# mta ridership - aggregated on 4hr intervals

mta = pd.read_csv('subway_2021_ridership.csv')
mta = mta[mta['flag'] == True]
mta.head()
# Out:
#   STATION            DATE_time   ENTRIES  ridership  flag
# 0    1 AV  2020-12-26 04:00:00  15510689        3.0  True
# 1    1 AV  2020-12-26 08:00:00  15510717       28.0  True
# 2    1 AV  2020-12-26 12:00:00  15510758       41.0  True
# 3    1 AV  2020-12-26 16:00:00  15510831       73.0  True
# 4    1 AV  2020-12-26 20:00:00  15510877       46.0  True

# %%
# aggregate on daily 

mta['DATE_time'] = pd.to_datetime(mta['DATE_time'])
mta['DATE'] = mta['DATE_time'].dt.date
mta_rider = mta.groupby(by=['DATE', 'STATION'], as_index=False).sum()[['DATE', 'STATION', 'ridership']]
mta_rider
# Out:
#               DATE          STATION  ridership
# 0       2020-12-26             1 AV      191.0
# 1       2020-12-26           103 ST      317.0
# 2       2020-12-26    103 ST-CORONA      703.0
# 3       2020-12-26           104 ST       20.0
# 4       2020-12-26           110 ST      239.0
# ...            ...              ...        ...
# 102331  2021-12-24   WOODHAVEN BLVD     1546.0
# 102332  2021-12-24         WOODLAWN      488.0
# 102333  2021-12-24  WORLD TRADE CTR      233.0
# 102334  2021-12-24          YORK ST      989.0
# 102335  2021-12-24        ZEREGA AV       80.0
#
# [102336 rows x 3 columns]

# %%
daily_rider = pd.pivot(data=mta_rider, index='DATE', columns=['STATION'], values='ridership')
daily_rider.head()
# Out:
# STATION      1 AV  103 ST  103 ST-CORONA  104 ST  110 ST  111 ST  116 ST  \
# DATE
# 2020-12-26  191.0   317.0          703.0    20.0   239.0    70.0    84.0
# 2020-12-27  159.0   366.0          649.0    19.0   229.0    87.0    65.0
# 2020-12-28  310.0   662.0          953.0    36.0   399.0   145.0   139.0
# 2020-12-29  390.0   678.0         1002.0    54.0   368.0   157.0   157.0
# 2020-12-30  402.0   680.0         1169.0    50.0   407.0   143.0   177.0
#
# STATION     121 ST  125 ST  135 ST  ...  WAKEFIELD/241  WALL ST  WHITLOCK AV  \
# DATE                                ...
# 2020-12-26   216.0   782.0     1.0  ...          267.0     53.0         35.0
# 2020-12-27   213.0   822.0     0.0  ...          315.0     46.0         20.0
# 2020-12-28   407.0  1226.0   536.0  ...          495.0    218.0         55.0
# 2020-12-29   420.0  1187.0    57.0  ...          478.0    227.0         48.0
# 2020-12-30   445.0  1116.0     NaN  ...          484.0    238.0         52.0
#
# STATION     WILSON AV  WINTHROP ST  WOODHAVEN BLVD  WOODLAWN  WORLD TRADE CTR  \
# DATE
# 2020-12-26      299.0        224.0           800.0     362.0             71.0
# 2020-12-27      253.0        188.0           696.0     349.0             60.0
# 2020-12-28      478.0        542.0          1079.0     663.0            173.0
# 2020-12-29      461.0        573.0          1430.0     686.0            178.0
# 2020-12-30      454.0        538.0          1195.0     696.0            173.0
#
# STATION     YORK ST  ZEREGA AV
# DATE
# 2020-12-26   7309.0       44.0
# 2020-12-27    447.0       47.0
# 2020-12-28    867.0      100.0
# 2020-12-29    896.0      123.0
# 2020-12-30    894.0      121.0
#
# [5 rows x 287 columns]

# %%
# keep last 60 days test, fist 300 training

test_dates = daily_rider.index[300:]
train_dates = daily_rider.index[:299]

# %%
# train-test split for nodes

np.random.seed(2002)

sub_list = mta_rider.STATION.unique()

nodes_known, nodes_mask = train_test_split(sub_list, test_size=0.25)

print(len(nodes_known), len(nodes_mask))
# Out:
# 215 72

# %% [markdown]
# $T_{i} = \sum w_{i,j}T_{j}$
#
# $w_{i,j}$ estimated with regression
#
# training for $t<T_0$

# %%
# run the model - using all stations T_j

def baseline4(model, station, data=daily_rider):

    print(station)
    # create train and test data
    data_train = daily_rider[daily_rider.index.isin(train_dates)]
    data_train.fillna(0, inplace=True)
    
    X_train = data_train.drop(columns={station}).values
    y_train = data_train[station].values  # y values as station ridership counts
    model.fit(X_train, y_train)
    pred = model.predict(X_train)
    
    print('train r2:', model.score(X_train, y_train))
    
    # test data X - all training nodes
    data_test = daily_rider.loc[daily_rider.index.isin(test_dates),
                        (daily_rider.columns.isin(nodes_known))]

    data_test.fillna(0, inplace=True)
    
    # create dataframe for the weights for each T_ij
    weights = pd.DataFrame(columns=data_train.drop(columns={station}).columns.values)
    weights.loc[0] = model.coef_
    
    weights = weights[data_test.columns]
    
    # y test (t>T0)
    y_test = daily_rider.loc[daily_rider.index.isin(test_dates),
                        station].values
    
    # get predictions for test set(T_i = sum w_i,j*T_j)
    pred = np.sum(weights.values*data_test.values, axis=1)
    
    print('test r2:', r2_score(y_test, pred))
    
    print('stations with high weights:', weights.sort_values(by=0, axis=1, ascending=False).columns[:5].values)
    print('\n')
    
    return (station, model.score(X_train, y_train), r2_score(y_test, pred))
    

all_stat = [baseline4(LinearRegression(fit_intercept=False, positive=True), stat) for stat in nodes_mask]
# Out:
# 14 ST
# train r2: 0.2714289962104798
# test r2: 0.8008463959925135
# stations with high weights: ['BROADWAY JCT' 'AQUEDUCT RACETR' 'CYPRESS HILLS' '3 AV' '80 ST']
#
#
# 157 ST
# train r2: 0.9080740628943865
# test r2: 0.7565003978638514
# stations with high weights: ['80 ST' 'PELHAM PKWY' 'AQUEDUCT RACETR' '168 ST' 'FRESH POND RD']
#
#
# EUCLID AV
# train r2: 0.816498896046304
# test r2: 0.30092516346966314
# stations with high weights: ['AQUEDUCT RACETR' '80 ST' 'INWOOD-207 ST' '168 ST' 'BAYCHESTER AV']
#
#
# HUNTS POINT AV
# train r2: 0.3789809791617498
# test r2: 0.22781486222236091
# stations with high weights: ['INWOOD-207 ST' '80 ST' 'PELHAM PKWY' 'DITMAS AV' 'W 8 ST-AQUARIUM']
#
#
# MARCY AV
# train r2: 0.8817328422211904
# test r2: -1.8326423788258364
# stations with high weights: ['INWOOD-207 ST' 'AQUEDUCT RACETR' '50 ST' '55 ST' 'AVENUE I']
#
#
# FLUSHING AV
# train r2: 0.9594835141226639
# test r2: -0.7074755092917819
# stations with high weights: ['DITMAS AV' 'FRESH POND RD' '80 ST' 'COURT SQ' '135 ST']
#
#
# 18 ST
# train r2: 0.9479866936838598
# test r2: -0.4317641127224563
# stations with high weights: ['AQUEDUCT RACETR' '80 ST' 'PELHAM PKWY' 'INWOOD-207 ST' '51 ST']
#
#
# GUN HILL RD
# train r2: 0.21977827817343054
# test r2: -6.153054532881758
# stations with high weights: ['FRANKLIN AV' 'BEACH 90 ST' 'HEWES ST' 'BAY RIDGE-95 ST' 'KINGSBRIDGE RD']
#
#
# 25 ST
# train r2: 0.8865949423103455
# test r2: -0.16652429213210262
# stations with high weights: ['80 ST' 'PELHAM PKWY' 'BROAD CHANNEL' 'LAFAYETTE AV' 'COURT SQ']
#
#
# MYRTLE-WYCKOFF
# train r2: 0.7997266488522676
# test r2: 0.40992489286489797
# stations with high weights: ['INWOOD-207 ST' 'DITMAS AV' 'HEWES ST' 'FRESH POND RD' '174-175 STS']
#
#
# MOSHOLU PKWY
# train r2: 0.8627337759214767
# test r2: 0.7530887029109739
# stations with high weights: ['80 ST' 'PELHAM PKWY' '155 ST' 'BROAD CHANNEL' '231 ST']
#
#
# JAMAICA VAN WK
# train r2: 0.6439326488579546
# test r2: 0.5058850203475107
# stations with high weights: ['80 ST' '8 AV' 'CLARK ST' '135 ST' 'FRANKLIN AV']
#
#
# PELHAM BAY PARK
# train r2: 0.7351420931693056
# test r2: 0.7782339985340796
# stations with high weights: ['PELHAM PKWY' 'NEPTUNE AV' 'ZEREGA AV' 'ST. GEORGE' 'SIMPSON ST']
#
#
# ELMHURST AV
# train r2: 0.07213817644897491
# test r2: -0.23704530448487593
# stations with high weights: ['80 ST' '155 ST' 'HEWES ST' 'FRANKLIN AV' 'PRINCE ST']
#
#
# GRAND ARMY PLAZ
# train r2: 0.9768407491863104
# test r2: 0.6581650612581423
# stations with high weights: ['BERGEN ST' '135 ST' 'ATLANTIC AV' 'CITY HALL' '5 AV/53 ST']
#
#
# WAKEFIELD/241
# train r2: 0.9013235865669177
# test r2: 0.2962612374057457
# stations with high weights: ['80 ST' 'PELHAM PKWY' 'FRESH POND RD' 'COURT SQ' 'AVENUE J']
#
#
# NOSTRAND AV
# train r2: 0.8167553624980692
# test r2: 0.16334014561299204
# stations with high weights: ['AQUEDUCT RACETR' '80 ST' 'LAFAYETTE AV' 'KINGSTON-THROOP'
#  'BROAD CHANNEL']
#
#
# MARBLE HILL-225
# train r2: 0.918005901815835
# test r2: 0.902464715809745
# stations with high weights: ['80 ST' 'DITMAS AV' 'INWOOD-207 ST' '207 ST' 'FT HAMILTON PKY']
#
#
# 34 ST-HERALD SQ
# train r2: 0.9259060614275216
# test r2: -0.5754747281806156
# stations with high weights: ['AQUEDUCT RACETR' 'PELHAM PKWY' 'DITMAS AV' 'INWOOD-207 ST' '51 ST']
#
#
# KINGS HWY
# train r2: 0.7029528330468562
# test r2: -0.48698741536563994
# stations with high weights: ['AQUEDUCT RACETR' '168 ST' 'PELHAM PKWY' 'DITMAS AV' 'CORTLANDT ST']
#
#
# GRAND-NEWTOWN
# train r2: 0.11592133265490745
# test r2: -2.4228782781953897
# stations with high weights: ['168 ST' 'AQUEDUCT RACETR' 'FRANKLIN AV' 'PRINCE ST' '74 ST-BROADWAY']
#
#
# ALABAMA AV
# train r2: 0.8339202073869624
# test r2: 0.6351384508788318
# stations with high weights: ['DITMAS AV' 'LEXINGTON AV/53' 'LAFAYETTE AV' 'NORWOOD AV' 'ASTORIA BLVD']
#
#
# GATES AV
# train r2: 0.9204297835939927
# test r2: -0.8056816504823796
# stations with high weights: ['PELHAM PKWY' '155 ST' 'FRESH POND RD' 'DITMAS AV' 'CHAUNCEY ST']
#
#
# 111 ST
# train r2: 0.8014712645611851
# test r2: 0.845122515202001
# stations with high weights: ['121 ST' 'HEWES ST' '104 ST' 'AVENUE M' 'BEACH 90 ST']
#
#
# KOSCIUSZKO ST
# train r2: 0.8441446956678438
# test r2: -0.5586084601897385
# stations with high weights: ['DITMAS AV' '80 ST' '168 ST' 'ELDER AV' 'NEW UTRECHT AV']
#
#
# SENECA AVE
# train r2: 0.9523259778633932
# test r2: -0.4479959087344725
# stations with high weights: ['80 ST' 'PELHAM PKWY' 'INWOOD-207 ST' 'AVENUE I' '116 ST']
#
#
# WOODLAWN
# train r2: 0.9786742721958459
# test r2: 0.6628694030856279
# stations with high weights: ['80 ST' 'LEXINGTON AV/53' 'GRANT AV' 'FRESH POND RD' 'BROADWAY JCT']
#
#
# 36 ST
# train r2: 0.8494314269493994
# test r2: -0.7845646740949805
# stations with high weights: ['80 ST' 'INWOOD-207 ST' 'PELHAM PKWY' 'DITMAS AV' 'NEW UTRECHT AV']
#
#
# NEW LOTS AV
# train r2: 0.8721254080216168
# test r2: -1.4710942511119751
# stations with high weights: ['DITMAS AV' '168 ST' 'FRESH POND RD' 'CYPRESS HILLS' 'SARATOGA AV']
#
#
# WOODHAVEN BLVD
# train r2: 0.43105773687837634
# test r2: -0.8422138763029663
# stations with high weights: ['AQUEDUCT RACETR' 'INWOOD-207 ST' 'PELHAM PKWY' 'DITMAS AV' 'WHITLOCK AV']
#
#
# 225 ST
# train r2: 0.970149856799427
# test r2: -0.5322821445675217
# stations with high weights: ['168 ST' 'PELHAM PKWY' '219 ST' 'CYPRESS HILLS' '183 ST']
#
#
# UNION ST
# train r2: 0.9460225635943313
# test r2: -0.01683327383696387
# stations with high weights: ['80 ST' 'AQUEDUCT RACETR' '168 ST' 'INWOOD-207 ST' 'PELHAM PKWY']
#
#
# LONGWOOD AV
# train r2: 0.6780525291654844
# test r2: 0.9282820055876596
# stations with high weights: ['PELHAM PKWY' 'INWOOD-207 ST' 'SIMPSON ST' '174 ST' "E 143/ST MARY'S"]
#
#
# MONTROSE AV
# train r2: 0.4169772491270518
# test r2: -0.894399942911698
# stations with high weights: ['PELHAM PKWY' 'DITMAS AV' 'AQUEDUCT RACETR' 'CLARK ST' 'HEWES ST']
#
#
# 215 ST
# train r2: 0.8610777330055197
# test r2: 0.5519519794100711
# stations with high weights: ['AQUEDUCT RACETR' '168 ST' 'LEXINGTON AV/53' '207 ST' 'NEPTUNE AV']
#
#
# BEDFORD AV
# train r2: 0.7626425423496019
# test r2: -1.1102392764365545
# stations with high weights: ['AQUEDUCT RACETR' 'PELHAM PKWY' 'DITMAS AV' 'INWOOD-207 ST' 'CLARK ST']
#
#
# 75 AV
# train r2: 0.33481995376601736
# test r2: -0.4422483985672734
# stations with high weights: ['168 ST' 'CORTLANDT ST' 'CLARK ST' 'LEXINGTON AV/53' 'FRESH POND RD']
#
#
# PENNSYLVANIA AV
# train r2: 0.9248791787708937
# test r2: -0.6626334096933437
# stations with high weights: ['INWOOD-207 ST' 'PELHAM PKWY' '80 ST' '168 ST' 'JUNIUS ST']
#
#
# SUTPHIN BLVD
# train r2: 0.13509915391356675
# test r2: -0.5107782184336338
# stations with high weights: ['80 ST' '8 AV' 'ASTORIA BLVD' 'HEWES ST' '1 AV']
#
#
# FRANKLIN ST
# train r2: 0.9486236452487998
# test r2: -0.23616039438291558
# stations with high weights: ['AQUEDUCT RACETR' '80 ST' 'DITMAS AV' 'ST. GEORGE' 'PELHAM PKWY']
#
#
# 125 ST
# train r2: 0.6838218827074336
# test r2: 0.40816434040066996
# stations with high weights: ['AQUEDUCT RACETR' '80 ST' '168 ST' 'DITMAS AV' 'CORTLANDT ST']
#
#
# BURNSIDE AV
# train r2: 0.8669494601080754
# test r2: -0.1061839563148208
# stations with high weights: ['51 ST' 'DITMAS AV' 'CROWN HTS-UTICA' 'BAYCHESTER AV' 'BEACH 60 ST']
#
#
# 169 ST
# train r2: 0.9174305670294451
# test r2: 0.7976262411547791
# stations with high weights: ['AQUEDUCT RACETR' 'BOTANIC GARDEN' 'DITMAS AV' '36 AV' 'HARLEM 148 ST']
#
#
# ALLERTON AV
# train r2: 0.947285288588603
# test r2: -0.2877846199825309
# stations with high weights: ['INWOOD-207 ST' 'AQUEDUCT RACETR' 'PELHAM PKWY' 'WHITLOCK AV' '219 ST']
#
#
# 79 ST
# train r2: 0.9017783006505536
# test r2: 0.1888929122557046
# stations with high weights: ['AQUEDUCT RACETR' 'PELHAM PKWY' '168 ST' 'CITY HALL' 'ST. GEORGE']
#
#
# 20 AV
# train r2: 0.9793364724848763
# test r2: 0.011325620240718814
# stations with high weights: ['INWOOD-207 ST' 'PELHAM PKWY' 'DITMAS AV' '9 AV' '168 ST']
#
#
# CYPRESS AV
# train r2: 0.9202244323806495
# test r2: 0.9572289481135665
# stations with high weights: ['PELHAM PKWY' 'DITMAS AV' '168 ST' '80 ST' 'E 149 ST']
#
#
# BEACH 25 ST
# train r2: 0.9350075122414181
# test r2: 0.9361298283096771
# stations with high weights: ['PELHAM PKWY' 'BEACH 36 ST' 'BEACH 44 ST' 'BEACH 60 ST' 'BOTANIC GARDEN']
#
#
# CANAL ST
# train r2: 0.9264662453485577
# test r2: -1.4052656124625829
# stations with high weights: ['INWOOD-207 ST' 'AQUEDUCT RACETR' 'DITMAS AV' 'LAFAYETTE AV' '49 ST']
#
#
# CLASSON AV
# train r2: 0.8731937149346716
# test r2: 0.6562019539894132
# stations with high weights: ['AQUEDUCT RACETR' 'INWOOD-207 ST' '9 AV' '6 AV' '21 ST']
#
#
# 90 ST-ELMHURST
# train r2: 0.6083036825650423
# test r2: -1.5377833484902816
# stations with high weights: ['AQUEDUCT RACETR' '168 ST' 'INWOOD-207 ST' 'CLARK ST' 'BEACH 44 ST']
#
#
# BROAD ST
# train r2: 0.9564345146253238
# test r2: 0.5739054353927919
# stations with high weights: ['DITMAS AV' 'BROAD CHANNEL' 'COURT SQ' 'LEXINGTON AV/53' 'FRESH POND RD']
#
#
# AVENUE N
# train r2: 0.06451331147570694
# test r2: -1.2149140703955736
# stations with high weights: ['DITMAS AV' 'AQUEDUCT RACETR' 'INWOOD-207 ST' 'HEWES ST' '174 ST']
#
#
# TIMES SQ-42 ST
# train r2: 0.9644444001604525
# test r2: 0.5636421531371801
# stations with high weights: ['80 ST' 'PELHAM PKWY' 'DITMAS AV' 'FRESH POND RD' 'COURT SQ']
#
#
# 167 ST
# train r2: 0.09673790987662367
# test r2: 0.49431772521346695
# stations with high weights: ['ASTORIA BLVD' 'HEWES ST' 'FRANKLIN AV' 'FREEMAN ST' 'FRESH POND RD']
#
#
# FOREST AVE
# train r2: 0.9336515302801767
# test r2: -0.9471738988819969
# stations with high weights: ['168 ST' 'DITMAS AV' 'FRANKLIN AV' 'RECTOR ST' "E 143/ST MARY'S"]
#
#
# 233 ST
# train r2: 0.6364856882059644
# test r2: 0.47398309334691857
# stations with high weights: ['AQUEDUCT RACETR' 'INWOOD-207 ST' 'PELHAM PKWY' '168 ST' '51 ST']
#
#
# MORRIS PARK
# train r2: 0.9023525190676205
# test r2: 0.8180275058442128
# stations with high weights: ['PELHAM PKWY' 'DITMAS AV' 'LEXINGTON AV/53' 'WHITLOCK AV' 'FRESH POND RD']
#
#
# BOWERY
# train r2: 0.7480846058022641
# test r2: -0.1002823285403942
# stations with high weights: ['80 ST' '8 ST-NYU' 'CLARK ST' 'CORTLANDT ST' '135 ST']
#
#
# JAY ST-METROTEC
# train r2: 0.9307321284629455
# test r2: 0.7487983157514962
# stations with high weights: ['AQUEDUCT RACETR' 'CITY HALL' 'CHAMBERS ST' 'FT HAMILTON PKY'
#  'LEXINGTON AV/53']
#
#
# 18 AV
# train r2: 0.9400009127318536
# test r2: -0.758334149358014
# stations with high weights: ['PELHAM PKWY' '168 ST' 'BROAD CHANNEL' 'DITMAS AV' '25 AV']
#
#
# LIBERTY AV
# train r2: 0.15537116681479446
# test r2: -2.792826179743885
# stations with high weights: ['BROAD CHANNEL' 'CYPRESS HILLS' 'AVENUE I' 'METS-WILLETS PT' '1 AV']
#
#
# SUTTER AV
# train r2: 0.8598840020622578
# test r2: 0.8013304186805643
# stations with high weights: ['80 ST' 'PELHAM PKWY' '168 ST' 'ATLANTIC AV' 'FRESH POND RD']
#
#
# CARROLL ST
# train r2: 0.8890091124855992
# test r2: 0.35222693490044155
# stations with high weights: ['PELHAM PKWY' '51 ST' '168 ST' 'BOTANIC GARDEN' 'FRANKLIN AV']
#
#
# WALL ST
# train r2: 0.9556458772063658
# test r2: 0.7064335561232861
# stations with high weights: ['AQUEDUCT RACETR' 'LEXINGTON AV/53' 'ST. GEORGE' '168 ST' 'CITY HALL']
#
#
# PROSPECT AV
# train r2: 0.9157744282743724
# test r2: 0.8047908770817721
# stations with high weights: ['PELHAM PKWY' 'COURT SQ' 'BROAD CHANNEL' 'JACKSON AV' 'CROWN HTS-UTICA']
#
#
# NEWKIRK PLAZA
# train r2: 0.8881710768419983
# test r2: 0.7520883723431353
# stations with high weights: ['80 ST' 'DITMAS AV' 'INWOOD-207 ST' '168 ST' '8 AV']
#
#
# PARSONS BLVD
# train r2: 0.17594528514245766
# test r2: -0.02004437042471574
# stations with high weights: ['AQUEDUCT RACETR' 'INWOOD-207 ST' 'PELHAM PKWY' '168 ST' 'HEWES ST']
#
#
# PARKCHESTER
# train r2: 0.8480460237313604
# test r2: 0.47996751980268126
# stations with high weights: ['80 ST' 'PELHAM PKWY' 'AQUEDUCT RACETR' 'COURT SQ' '135 ST']
#
#
# ROOSEVELT ISLND
# train r2: 0.7342656534720343
# test r2: -4.90430379239531
# stations with high weights: ['INWOOD-207 ST' '168 ST' 'CLARK ST' 'DITMAS AV' 'W 8 ST-AQUARIUM']
#
#
# TOMPKINSVILLE
# train r2: 0.7376219780065517
# test r2: 0.7273601329047183
# stations with high weights: ['80 ST' 'ST. GEORGE' 'KINGSTON-THROOP' 'DITMAS AV' 'FRANKLIN AV']
#
#
# 14 ST-UNION SQ
# train r2: 0.873880037863648
# test r2: 0.12098344836636954
# stations with high weights: ['AQUEDUCT RACETR' 'LEXINGTON AV/53' 'PELHAM PKWY' '51 ST'
#  'BOTANIC GARDEN']

# %%
#connection list
links = pd.read_csv( 'https://raw.githubusercontent.com/CUSP2021ADS/Data/main/NYCSubwayEdges.csv' , index_col=None, header=0 )
links.head()
# Out:
#   origin dest
# 0    G26  G24
# 1    G26  G28
# 2    G24  G26
# 3    G24  G22
# 4    G22  G24

# %%
# locations

mta_loc = pd.read_csv('subway_locations_connections.csv')
mta_loc.head()
# Out:
#              origin_name origin_id  origin_lat  origin_long  \
# 0                   1 AV       L06   40.730953   -73.981628
# 1                 103 ST       119   40.799446   -73.968379
# 2  103 ST - CORONA PLAZA       706   40.749865   -73.862700
# 3                 104 ST       A63   40.681711   -73.837683
# 4                 110 ST       623   40.795020   -73.944250
#
#                      dest_name         dest_id                dest_lat  \
# 0       ['3 Av', 'Bedford Av']  ['L05', 'L08']  [40.732849, 40.717304]
# 1  ['96 St', 'Cathedral Pkwy']  ['120', '118']  [40.793919, 40.803967]
# 2  ['Junction Blvd', '111 St']  ['707', '705']   [40.749145, 40.75173]
# 3  ['111 St', 'Rockaway Blvd']  ['A64', 'A61']  [40.684331, 40.680429]
# 4         ['116 St', '103 St']  ['622', '624']    [40.798629, 40.7906]
#
#                   dest_long
# 0  [-73.986122, -73.956872]
# 1  [-73.972323, -73.966847]
# 2  [-73.869527, -73.855334]
# 3  [-73.832163, -73.843853]
# 4  [-73.941617, -73.947478]

# %%
# get 5 neighbors for each station

X_train, y_train = mta_loc[['origin_lat', 'origin_long']], mta_loc[['origin_id']]
mod = KNeighborsRegressor(n_neighbors=6, metric='haversine')
mod.fit(X_train, y_train)
dist, ind = mod.kneighbors(X_train)

# %%
# run the model - using just 5 neighboring stations T_j

def baseline4(model, station, data=daily_rider):

    print(station)
    
    # get 
    try:
        neib = mta_loc[mta_loc.index.isin(ind[mta_loc[mta_loc.origin_name == station].index][0][1:])]['origin_name'].values
        print(neib)
    except:
        neib = []
    # create train and test data
    data_train = daily_rider[daily_rider.index.isin(train_dates)]
    data_train.fillna(0, inplace=True)
    
    if len(neib) != 0:
        X_train = data_train[[i for i in neib if i in data_train.columns]]
        y_train = data_train[station].values  # y values as station ridership counts
        print(X_train.shape)
        if X_train.shape[1] != 0:     

            model.fit(X_train, y_train)
            pred = model.predict(X_train)

            print('train r2:', model.score(X_train, y_train))
            
            data_test = daily_rider.loc[daily_rider.index.isin(test_dates),
                        (daily_rider.columns.isin(nodes_known))]

            data_test.fillna(0, inplace=True)

            # create dataframe for the weights for each T_ij
            weights = pd.DataFrame(columns=X_train.columns)
            weights.loc[0] = model.coef_

            data_test = data_test[[i for i in neib if i in data_test.columns]]

            weights = weights[data_test.columns]

            # y test (t>T0)
            y_test = daily_rider.loc[daily_rider.index.isin(test_dates),
                                station].values

            # get predictions for test set(T_i = sum w_i,j*T_j)
            pred = np.sum(weights.values*data_test.values, axis=1)

            print('test r2:', r2_score(y_test, pred))

            print('stations with high weights:', weights.sort_values(by=0, axis=1, ascending=False).columns[:5].values)
            print('\n')

            return (station, model.score(X_train, y_train), r2_score(y_test, pred))
        else:
            pass
    else:
        pass

stat_5 = [baseline4(LinearRegression(fit_intercept=False, positive=True), stat) for stat in nodes_mask]
# Out:
# 14 ST
# ['18 ST' '6 AV' '8 AV' 'CHRISTOPHER ST - SHERIDAN SQ' 'W 4 ST']
# (299, 3)
# train r2: 0.14853452066591932
# test r2: -4.357961734418532
# stations with high weights: ['6 AV' '8 AV']
#
#
# 157 ST
# ['145 ST' '155 ST' '163 ST - AMSTERDAM AV' '168 ST'
#  '168 ST - WASHINGTON HTS']
# (299, 3)
# train r2: 0.5045654025563787
# test r2: 0.23862469918709195
# stations with high weights: ['168 ST' '155 ST' '145 ST']
#
#
# EUCLID AV
# ['CLEVELAND ST' 'CRESCENT ST' 'GRANT AV' 'NORWOOD AV' 'SHEPHERD AV']
# (299, 5)
# train r2: 0.7195720073907732
# test r2: 0.7271662110767482
# stations with high weights: ['GRANT AV' 'SHEPHERD AV' 'NORWOOD AV' 'CRESCENT ST' 'CLEVELAND ST']
#
#
# HUNTS POINT AV
# ['FREEMAN ST' 'INTERVALE AV' 'LONGWOOD AV' 'SIMPSON ST' 'WHITLOCK AV']
# (299, 5)
# train r2: 0.16947096723306854
# test r2: -1.208375798868257
# stations with high weights: ['INTERVALE AV' 'FREEMAN ST' 'SIMPSON ST' 'WHITLOCK AV']
#
#
# MARCY AV
# ['BEDFORD AV' 'BROADWAY' 'HEWES ST' 'LORIMER ST' 'METROPOLITAN AV']
# (299, 5)
# train r2: 0.6658203595338219
# test r2: 0.5900724216117881
# stations with high weights: ['METROPOLITAN AV' 'BROADWAY' 'LORIMER ST' 'HEWES ST']
#
#
# FLUSHING AV
# ['BEDFORD - NOSTRAND AVS' 'BROADWAY' 'HEWES ST' 'MARCY AV'
#  'MYRTLE - WILLOUGHBY AVS']
# (299, 3)
# train r2: 0.8290458498244486
# test r2: -2.620356171504438
# stations with high weights: ['BROADWAY' 'HEWES ST']
#
#
# 18 ST
# ['14 ST' '23 ST' '28 ST' '6 AV' '8 AV']
# (299, 5)
# train r2: 0.9002778431253283
# test r2: 0.6643659240855716
# stations with high weights: ['23 ST' '28 ST' '8 AV' '6 AV']
#
#
# GUN HILL RD
# ['219 ST' '225 ST' 'ALLERTON AV' 'BURKE AV' 'NORWOOD - 205 ST']
# (299, 4)
# train r2: -0.0015819158865819638
# test r2: -9.101402877137453
# stations with high weights: ['219 ST' 'BURKE AV']
#
#
# 25 ST
# ['4 AV' '45 ST' '9 AV' '9 ST' 'SMITH - 9 STS']
# (299, 2)
# train r2: 0.7519262020772897
# test r2: 0.7378909632702191
# stations with high weights: ['9 AV' '45 ST']
#
#
# MYRTLE-WYCKOFF
# MOSHOLU PKWY
# ['BEDFORD PARK BLVD' 'BEDFORD PARK BLVD - LEHMAN COLLEGE'
#  'NORWOOD - 205 ST' 'VAN CORTLANDT PARK - 242 ST' 'WOODLAWN']
# (299, 1)
# train r2: 0.7394488220734257
# test r2: -12.182319927670752
# stations with high weights: []
#
#
# JAMAICA VAN WK
# PELHAM BAY PARK
# ['BAYCHESTER AV' 'BUHRE AV' 'MIDDLETOWN RD'
#  'WESTCHESTER SQ - E TREMONT AV' 'ZEREGA AV']
# (299, 4)
# train r2: 0.6966535720470639
# test r2: 0.7100615061778708
# stations with high weights: ['ZEREGA AV' 'MIDDLETOWN RD' 'BAYCHESTER AV' 'BUHRE AV']
#
#
# ELMHURST AV
# ['74 ST - BROADWAY' '82 ST - JACKSON HTS' '90 ST - ELMHURST AV'
#  'GRAND AV - NEWTOWN' 'JACKSON HTS - ROOSEVELT AV']
# (299, 0)
# GRAND ARMY PLAZ
# WAKEFIELD/241
# NOSTRAND AV
# ['BOTANIC GARDEN' 'FRANKLIN AV' 'KINGSTON AV' 'PRESIDENT ST' 'STERLING ST']
# (299, 5)
# train r2: 0.6145062899386509
# test r2: 0.6311435922555343
# stations with high weights: ['STERLING ST' 'BOTANIC GARDEN' 'KINGSTON AV' 'PRESIDENT ST' 'FRANKLIN AV']
#
#
# MARBLE HILL-225
# 34 ST-HERALD SQ
# KINGS HWY
# ['AVENUE J' 'AVENUE M' 'AVENUE P' 'AVENUE U' 'NECK RD']
# (299, 5)
# train r2: 0.2803239639032936
# test r2: 0.46920972136997774
# stations with high weights: ['NECK RD' 'AVENUE U' 'AVENUE J' 'AVENUE M' 'AVENUE P']
#
#
# GRAND-NEWTOWN
# ALABAMA AV
# ['ATLANTIC AV' 'BROADWAY JCT' 'BUSHWICK AV - ABERDEEN ST' 'LIBERTY AV'
#  'SUTTER AV']
# (299, 4)
# train r2: 0.5016883026957266
# test r2: -0.20863126537971466
# stations with high weights: ['BROADWAY JCT' 'ATLANTIC AV']
#
#
# GATES AV
# ['CHAUNCEY ST' 'HALSEY ST' 'KOSCIUSZKO ST' 'RALPH AV' 'UTICA AV']
# (299, 5)
# train r2: 0.8388013617718407
# test r2: -0.11709946193152532
# stations with high weights: ['CHAUNCEY ST' 'UTICA AV' 'HALSEY ST' 'RALPH AV']
#
#
# 111 ST
# ['103 ST - CORONA PLAZA' '63 DR - REGO PARK' '90 ST - ELMHURST AV'
#  'JUNCTION BLVD' 'METS - WILLETS POINT']
# (299, 1)
# train r2: -0.28806805397734925
# test r2: -0.9921848548870538
# stations with high weights: ['JUNCTION BLVD']
#
#
# KOSCIUSZKO ST
# ['GATES AV' 'HALSEY ST' 'MORGAN AV' 'MYRTLE AV' 'UTICA AV']
# (299, 5)
# train r2: 0.7721144565080031
# test r2: -1.977273858129934
# stations with high weights: ['MORGAN AV' 'HALSEY ST' 'UTICA AV' 'MYRTLE AV']
#
#
# SENECA AVE
# WOODLAWN
# ['219 ST' 'BEDFORD PARK BLVD' 'GUN HILL RD' 'MOSHOLU PKWY'
#  'NORWOOD - 205 ST']
# (299, 3)
# train r2: 0.9057100155234523
# test r2: 0.579910703826884
# stations with high weights: ['219 ST']
#
#
# 36 ST
# ['36 AV' '39 AV' '40 ST' 'QUEENS PLAZA' 'STEINWAY ST']
# (299, 4)
# train r2: 0.22885720770908735
# test r2: -0.28696892447448374
# stations with high weights: ['39 AV' '36 AV' 'STEINWAY ST' 'QUEENS PLAZA']
#
#
# NEW LOTS AV
# ['CLEVELAND ST' 'LIBERTY AV' 'PENNSYLVANIA AV' 'SHEPHERD AV'
#  'VAN SICLEN AV']
# (299, 5)
# train r2: 0.7302594254648732
# test r2: -5.05254657636067
# stations with high weights: ['VAN SICLEN AV' 'SHEPHERD AV' 'CLEVELAND ST']
#
#
# WOODHAVEN BLVD
# ['63 DR - REGO PARK' '90 ST - ELMHURST AV' 'ELMHURST AV'
#  'GRAND AV - NEWTOWN' 'JUNCTION BLVD']
# (299, 2)
# train r2: 0.27627470709051694
# test r2: 0.021719247137074404
# stations with high weights: ['JUNCTION BLVD']
#
#
# 225 ST
# ['219 ST' '233 ST' 'GUN HILL RD' 'NEREID AV' 'WAKEFIELD - 241 ST']
# (299, 4)
# train r2: 0.9260498976702604
# test r2: 0.9571248332570274
# stations with high weights: ['219 ST' 'NEREID AV']
#
#
# UNION ST
# ['4 AV' '9 ST' 'ATLANTIC AV - BARCLAYS CTR' 'BERGEN ST' 'NEVINS ST']
# (299, 2)
# train r2: 0.8508477834320692
# test r2: 0.7583925524421286
# stations with high weights: ['NEVINS ST' 'BERGEN ST']
#
#
# LONGWOOD AV
# ['E 149 ST' 'HUNTS POINT AV' 'INTERVALE AV' 'PROSPECT AV' 'SIMPSON ST']
# (299, 5)
# train r2: 0.6207356206465721
# test r2: 0.8027157996285925
# stations with high weights: ['SIMPSON ST' 'E 149 ST' 'INTERVALE AV']
#
#
# MONTROSE AV
# ['BROADWAY' 'GRAHAM AV' 'LORIMER ST' 'MORGAN AV' 'MYRTLE AV']
# (299, 5)
# train r2: 0.1547057261601652
# test r2: -1.5156875380239194
# stations with high weights: ['MORGAN AV' 'BROADWAY' 'MYRTLE AV' 'LORIMER ST' 'GRAHAM AV']
#
#
# 215 ST
# ['207 ST' '231 ST' 'DYCKMAN ST' 'INWOOD - 207 ST' 'MARBLE HILL - 225 ST']
# (299, 3)
# train r2: 0.7654963327287377
# test r2: 0.4777597789329412
# stations with high weights: ['207 ST' '231 ST' 'DYCKMAN ST']
#
#
# BEDFORD AV
# ['HEWES ST' 'LORIMER ST' 'MARCY AV' 'METROPOLITAN AV' 'NASSAU AV']
# (299, 5)
# train r2: 0.2866540222176087
# test r2: -1.5782296372071616
# stations with high weights: ['METROPOLITAN AV' 'LORIMER ST' 'HEWES ST' 'NASSAU AV']
#
#
# 75 AV
# ['121 ST' '67 AV' 'BRIARWOOD - VAN WYCK BLVD' 'FOREST HILLS - 71 AV'
#  'KEW GARDENS - UNION TPKE']
# (299, 2)
# train r2: -0.03581295628310133
# test r2: -0.4782473636519313
# stations with high weights: ['67 AV' '121 ST']
#
#
# PENNSYLVANIA AV
# ['JUNIUS ST' 'LIBERTY AV' 'LIVONIA AV' 'SUTTER AV' 'VAN SICLEN AV']
# (299, 5)
# train r2: 0.8478024592326925
# test r2: 0.3300236310534228
# stations with high weights: ['JUNIUS ST' 'VAN SICLEN AV' 'LIVONIA AV']
#
#
# SUTPHIN BLVD
# ['BRIARWOOD - VAN WYCK BLVD' 'JAMAICA - VAN WYCK'
#  'JAMAICA CENTER - PARSONS/ARCHER' 'PARSONS BLVD'
#  'SUTPHIN BLVD - ARCHER AV - JFK AIRPORT']
# (299, 1)
# train r2: 0.04067499256616092
# test r2: -0.6969271290605794
# stations with high weights: []
#
#
# FRANKLIN ST
# ['BROOKLYN BRIDGE - CITY HALL' 'CANAL ST' 'CHAMBERS ST' 'CITY HALL'
#  'PARK PL']
# (299, 3)
# train r2: 0.8394200526442265
# test r2: -1.307904627833714
# stations with high weights: ['CITY HALL' 'CHAMBERS ST']
#
#
# 125 ST
# ['116 ST - COLUMBIA UNIVERSITY' '137 ST - CITY COLLEGE' '145 ST'
#  'CATHEDRAL PKWY' 'CATHEDRAL PKWY (110 ST)']
# (299, 2)
# train r2: 0.3733396726482382
# test r2: -0.04880822791725703
# stations with high weights: ['CATHEDRAL PKWY' '145 ST']
#
#
# BURNSIDE AV
# ['174-175 STS' '176 ST' '182-183 STS' '183 ST' 'TREMONT AV']
# (299, 5)
# train r2: 0.8084484590887789
# test r2: 0.8914585385135416
# stations with high weights: ['183 ST' '174-175 STS' '182-183 STS' '176 ST' 'TREMONT AV']
#
#
# 169 ST
# ['JAMAICA - 179 ST' 'JAMAICA CENTER - PARSONS/ARCHER' 'PARSONS BLVD'
#  'SUTPHIN BLVD' 'SUTPHIN BLVD - ARCHER AV - JFK AIRPORT']
# (299, 2)
# train r2: -5.911045109387701
# test r2: -7.607263125538029
# stations with high weights: []
#
#
# ALLERTON AV
# ['BURKE AV' 'GUN HILL RD' 'MORRIS PARK' 'NORWOOD - 205 ST' 'PELHAM PKWY']
# (299, 4)
# train r2: 0.8705366721755228
# test r2: 0.835613223187244
# stations with high weights: ['PELHAM PKWY' 'BURKE AV']
#
#
# 79 ST
# ['66 ST - LINCOLN CENTER' '72 ST' '81 ST - MUSEUM OF NATURAL HISTORY'
#  '86 ST' '96 ST']
# (299, 3)
# train r2: 0.7768866980200297
# test r2: 0.6597926649875817
# stations with high weights: ['96 ST' '72 ST' '86 ST']
#
#
# 20 AV
# ['18 AV' '25 AV' '71 ST' 'BAY PKWY' 'NEW UTRECHT AV']
# (299, 5)
# train r2: 0.9440114683028707
# test r2: -0.48456348266630256
# stations with high weights: ['NEW UTRECHT AV' '25 AV' '71 ST' 'BAY PKWY']
#
#
# CYPRESS AV
# ['3 AV - 149 ST' 'BROOK AV' "E 143 ST - ST MARY'S ST" 'E 149 ST'
#  'JACKSON AV']
# (299, 3)
# train r2: 0.8908364033841928
# test r2: 0.9668198384384985
# stations with high weights: ['E 149 ST' 'BROOK AV' 'JACKSON AV']
#
#
# BEACH 25 ST
# ['BEACH 36 ST' 'BEACH 44 ST' 'BEACH 60 ST' 'BEACH 67 ST'
#  'FAR ROCKAWAY - MOTT AV']
# (299, 4)
# train r2: 0.8821216999670025
# test r2: 0.8933170022889292
# stations with high weights: ['BEACH 36 ST' 'BEACH 44 ST' 'BEACH 60 ST' 'BEACH 67 ST']
#
#
# CANAL ST
# ['CHAMBERS ST' 'FRANKLIN ST' 'HOUSTON ST' 'PRINCE ST' 'SPRING ST']
# (299, 5)
# train r2: 0.7414410179360715
# test r2: 0.29075694469035795
# stations with high weights: ['HOUSTON ST' 'SPRING ST' 'CHAMBERS ST' 'PRINCE ST']
#
#
# CLASSON AV
# ['BEDFORD - NOSTRAND AVS' 'CLINTON - WASHINGTON AVS' 'FLUSHING AV'
#  'LAFAYETTE AV' 'MYRTLE - WILLOUGHBY AVS']
# (299, 2)
# train r2: 0.6627776660725241
# test r2: -6.6945579811199565
# stations with high weights: ['LAFAYETTE AV']
#
#
# 90 ST-ELMHURST
# BROAD ST
# ['BOWLING GREEN' 'FULTON ST' 'RECTOR ST' 'WALL ST' 'WHITEHALL ST']
# (299, 4)
# train r2: 0.8496190207819491
# test r2: 0.3589469097918354
# stations with high weights: ['RECTOR ST' 'BOWLING GREEN' 'FULTON ST']
#
#
# AVENUE N
# ['AVENUE I' 'AVENUE J' 'AVENUE M' 'AVENUE P' 'KINGS HWY']
# (299, 5)
# train r2: 0.008780589470302358
# test r2: -1.4116631994934532
# stations with high weights: ['AVENUE P' 'AVENUE J' 'AVENUE I' 'AVENUE M']
#
#
# TIMES SQ-42 ST
# 167 ST
# ['161 ST - YANKEE STADIUM' '170 ST' '174-175 STS' '176 ST' 'MT EDEN AV']
# (299, 4)
# train r2: 0.03339541580429162
# test r2: 0.598032010498722
# stations with high weights: ['174-175 STS' 'MT EDEN AV' '170 ST' '176 ST']
#
#
# FOREST AVE
# 233 ST
# ['219 ST' '225 ST' 'GUN HILL RD' 'NEREID AV' 'WAKEFIELD - 241 ST']
# (299, 4)
# train r2: 0.49973088675217725
# test r2: 0.9346033504486932
# stations with high weights: ['NEREID AV' '219 ST']
#
#
# MORRIS PARK
# ['ALLERTON AV' 'BRONX PARK EAST' 'BURKE AV' 'E 180 ST' 'PELHAM PKWY']
# (299, 5)
# train r2: 0.7900769489936688
# test r2: 0.7322734575437089
# stations with high weights: ['PELHAM PKWY' 'BRONX PARK EAST' 'BURKE AV' 'E 180 ST']
#
#
# BOWERY
# ['2 AV' 'BROADWAY-LAFAYETTE ST' 'GRAND ST' 'PRINCE ST' 'SPRING ST']
# (299, 4)
# train r2: 0.6042672049649433
# test r2: 0.2135500466852076
# stations with high weights: ['PRINCE ST' '2 AV' 'SPRING ST' 'GRAND ST']
#
#
# JAY ST-METROTEC
# 18 AV
# ['20 AV' '25 AV' '71 ST' 'BAY PKWY' 'NEW UTRECHT AV']
# (299, 5)
# train r2: 0.8947687515882534
# test r2: -5.202605991166177
# stations with high weights: ['NEW UTRECHT AV' '25 AV' '71 ST' 'BAY PKWY']
#
#
# LIBERTY AV
# ['ALABAMA AV' 'ATLANTIC AV' 'BROADWAY JCT' 'PENNSYLVANIA AV' 'SUTTER AV']
# (299, 5)
# train r2: 0.0670422539941915
# test r2: -2.885986971900971
# stations with high weights: ['ATLANTIC AV' 'BROADWAY JCT']
#
#
# SUTTER AV
# ['ALABAMA AV' 'ATLANTIC AV' 'JUNIUS ST' 'LIBERTY AV' 'LIVONIA AV']
# (299, 5)
# train r2: 0.7808552325699611
# test r2: 0.8889848401749676
# stations with high weights: ['ATLANTIC AV' 'JUNIUS ST' 'LIVONIA AV']
#
#
# CARROLL ST
# ['4 AV' '9 ST' 'HOYT - SCHERMERHORN STS' 'SMITH - 9 STS' 'UNION ST']
# (299, 1)
# train r2: 0.7253918065666294
# test r2: -5.494777937150419
# stations with high weights: []
#
#
# WALL ST
# ['BOWLING GREEN' 'BROAD ST' 'FULTON ST' 'RECTOR ST' 'WHITEHALL ST']
# (299, 4)
# train r2: 0.9291016968270536
# test r2: 0.8484799292132286
# stations with high weights: ['BOWLING GREEN' 'RECTOR ST' 'FULTON ST']
#
#
# PROSPECT AV
# ['E 149 ST' 'INTERVALE AV' 'JACKSON AV' 'LONGWOOD AV' 'SIMPSON ST']
# (299, 5)
# train r2: 0.8396739410643582
# test r2: 0.9220346429533959
# stations with high weights: ['JACKSON AV' 'INTERVALE AV' 'SIMPSON ST' 'E 149 ST']
#
#
# NEWKIRK PLAZA
# ['AVENUE H' 'AVENUE J' 'BEVERLEY RD' 'CORTELYOU RD' 'NEWKIRK AV']
# (299, 4)
# train r2: 0.7875053370636461
# test r2: 0.9257039937988566
# stations with high weights: ['CORTELYOU RD' 'AVENUE J' 'NEWKIRK AV' 'AVENUE H']
#
#
# PARSONS BLVD
# ['169 ST' 'JAMAICA - VAN WYCK' 'JAMAICA CENTER - PARSONS/ARCHER'
#  'SUTPHIN BLVD' 'SUTPHIN BLVD - ARCHER AV - JFK AIRPORT']
# (299, 2)
# train r2: 0.06389018213712294
# test r2: -0.021398537215920443
# stations with high weights: []
#
#
# PARKCHESTER
# ['CASTLE HILL AV' 'E 180 ST' 'MORRISON AV- SOUND VIEW' 'ST LAWRENCE AV'
#  'ZEREGA AV']
# (299, 4)
# train r2: 0.7136348940357177
# test r2: 0.6802981268604134
# stations with high weights: ['ST LAWRENCE AV' 'ZEREGA AV' 'CASTLE HILL AV' 'E 180 ST']
#
#
# ROOSEVELT ISLND
# TOMPKINSVILLE
# ['CLIFTON' 'GRASMERE' 'OLD TOWN' 'ST GEORGE' 'STAPLETON']
# (299, 0)
# 14 ST-UNION SQ

# %%
stat_all = pd.DataFrame(all_stat).rename(columns={0:'station', 1:'train_r2_allStat', 2:'test_r2_allStat'})
stat5 = pd.DataFrame(stat_5).rename(columns={0:'station', 1:'train_r2_5Stat', 2:'test_r2_5Stat'})

# %%
stat_all.merge(stat5, on='station')
# Out:
#             station  train_r2_allStat  test_r2_allStat  train_r2_5Stat  \
# 0             14 ST          0.271429         0.800846        0.148535
# 1            157 ST          0.908074         0.756500        0.339241
# 2         EUCLID AV          0.816499         0.300925        0.719572
# 3    HUNTS POINT AV          0.378981         0.227815        0.169467
# 4          MARCY AV          0.881733        -1.832642        0.659288
# 5       FLUSHING AV          0.959484        -0.707476        0.829046
# 6             18 ST          0.947987        -0.431764        0.889247
# 7       GUN HILL RD          0.219778        -6.153055       -0.001582
# 8             25 ST          0.886595        -0.166524        0.543750
# 9      MOSHOLU PKWY          0.862734         0.753089        0.739449
# 10  PELHAM BAY PARK          0.735142         0.778234        0.690903
# 11      NOSTRAND AV          0.816755         0.163340        0.596410
# 12        KINGS HWY          0.702953        -0.486987        0.280324
# 13       ALABAMA AV          0.833920         0.635138        0.501688
# 14         GATES AV          0.920430        -0.805682        0.827193
# 15           111 ST          0.801471         0.845123       -0.288068
# 16    KOSCIUSZKO ST          0.844145        -0.558608        0.771889
# 17         WOODLAWN          0.978674         0.662869        0.769082
# 18            36 ST          0.849431        -0.784565        0.228857
# 19      NEW LOTS AV          0.872125        -1.471094        0.726776
# 20   WOODHAVEN BLVD          0.431058        -0.842214        0.276275
# 21           225 ST          0.970150        -0.532282        0.926050
# 22         UNION ST          0.946023        -0.016833        0.743878
# 23      LONGWOOD AV          0.678053         0.928282        0.558011
# 24      MONTROSE AV          0.416977        -0.894400        0.154591
# 25           215 ST          0.861078         0.551952        0.763394
# 26       BEDFORD AV          0.762643        -1.110239        0.286654
# 27            75 AV          0.334820        -0.442248       -0.076369
# 28  PENNSYLVANIA AV          0.924879        -0.662633        0.847802
# 29     SUTPHIN BLVD          0.135099        -0.510778        0.040675
# 30      FRANKLIN ST          0.948624        -0.236160        0.839420
# 31           125 ST          0.683822         0.408164        0.373340
# 32      BURNSIDE AV          0.866949        -0.106184        0.792209
# 33           169 ST          0.917431         0.797626       -6.119983
# 34      ALLERTON AV          0.947285        -0.287785        0.870537
# 35            79 ST          0.901778         0.188893        0.654369
# 36            20 AV          0.979336         0.011326        0.936176
# 37       CYPRESS AV          0.920224         0.957229        0.888678
# 38      BEACH 25 ST          0.935008         0.936130        0.882122
# 39         CANAL ST          0.926466        -1.405266        0.701184
# 40       CLASSON AV          0.873194         0.656202       -0.142352
# 41         BROAD ST          0.956435         0.573905        0.847843
# 42         AVENUE N          0.064513        -1.214914        0.008781
# 43           167 ST          0.096738         0.494318        0.033395
# 44           233 ST          0.636486         0.473983        0.499731
# 45      MORRIS PARK          0.902353         0.818028        0.786301
# 46           BOWERY          0.748085        -0.100282        0.401916
# 47            18 AV          0.940001        -0.758334        0.891606
# 48       LIBERTY AV          0.155371        -2.792826        0.067042
# 49        SUTTER AV          0.859884         0.801330        0.776370
# 50       CARROLL ST          0.889009         0.352227        0.725392
# 51          WALL ST          0.955646         0.706434        0.929102
# 52      PROSPECT AV          0.915774         0.804791        0.838025
# 53    NEWKIRK PLAZA          0.888171         0.752088        0.775595
# 54     PARSONS BLVD          0.175945        -0.020044        0.063890
# 55      PARKCHESTER          0.848046         0.479968        0.703283
#
#     test_r2_5Stat
# 0       -4.357962
# 1       -2.043952
# 2        0.727166
# 3       -1.211600
# 4        0.621457
# 5       -2.620356
# 6        0.591439
# 7       -9.101403
# 8        0.497269
# 9      -12.182320
# 10       0.692333
# 11       0.774286
# 12       0.469210
# 13      -0.208631
# 14      -0.935880
# 15      -0.992185
# 16      -2.153794
# 17     -10.177087
# 18      -0.286969
# 19      -4.677987
# 20       0.021719
# 21       0.957125
# 22       0.680674
# 23       0.187184
# 24      -1.582912
# 25       0.460955
# 26      -1.578230
# 27      -0.621502
# 28       0.330024
# 29      -0.696927
# 30      -1.307905
# 31      -0.048808
# 32       0.821372
# 33      -7.607263
# 34       0.835613
# 35       0.649375
# 36      -2.103606
# 37       0.965665
# 38       0.893317
# 39      -2.377227
# 40       0.225053
# 41       0.357480
# 42      -1.411663
# 43       0.598032
# 44       0.934603
# 45       0.730810
# 46       0.276711
# 47      -8.208650
# 48      -2.885987
# 49       0.712801
# 50      -5.494778
# 51       0.848480
# 52       0.895001
# 53       0.897538
# 54      -0.021399
# 55       0.586979
